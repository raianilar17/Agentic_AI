# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Write an details and cover multiple angle essay on topic {topic} as a professionaly Writer
    """ 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Analyse given {draft} as a professional Analyser.
    Present details feedback such structure, clarity, strength of argument, and writing style.
    """ 

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Rewrite Essay based on given reflection {reflection} for original_draft {original_draft}
    Essay should be professionally and technically sound great with all sentence should be 
    meaningful and realistic.
    """ 

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: Navigating the Digital Frontier: Should Social Media Platforms Be Regulated by the Government?
#
# Introduction
#
# In the digital age, social media has become an omnipresent force, shaping how we communicate, engage, and perceive the world. Platforms like Facebook, Twitter, Instagram, and TikTok have not only reshaped our social interactions but also positioned themselves as powerful tools for information dissemination, marketing, and political campaigning. However, their pervasive influence raises a critical question: should social media platforms be regulated by the government? This issue is complex and multi-faceted, touching on themes of free speech, censorship, privacy, corporate responsibility, and public safety. This essay will explore these angles to provide a nuanced perspective on whether government regulation is necessary or detrimental to the digital ecosystem.
#
# Free Speech and Censorship
#
# One of the primary arguments against government regulation of social media is the potential infringement on free speech. Social media platforms serve as modern-day public squares where individuals express opinions and engage in debates. Critics of regulation argue that government oversight could lead to censorship, stifling diverse voices and political dissent. They fear that allowing the government to dictate content standards could suppress unpopular or minority opinions, thereby weakening democratic principles.
#
# On the other hand, proponents of regulation contend that these platforms already exercise significant control over what is visible or hidden through their algorithms and moderation policies. They argue that without oversight, social media giants can continue to act as gatekeepers of information, often driven by corporate interests rather than the public good. Regulating these platforms could establish clear guidelines and accountability, ensuring that free speech is balanced with the need to protect users from harmful content, misinformation, and hate speech.
#
# Privacy Concerns
#
# Another compelling angle involves privacy concerns. Social media platforms collect vast amounts of personal data from their users, which is often used for targeted advertising and third-party sharing. Advocates for regulation argue that stringent laws are necessary to protect users' privacy rights and prevent data exploitation. The General Data Protection Regulation (GDPR) in the European Union serves as an example of how government regulation can enforce transparency and data protection standards.
#
# Conversely, opponents argue that overly strict regulations could stifle innovation and growth within the tech industry. They believe that companies should have the freedom to develop technologies that maximize user engagement and business success, maintaining that any restrictions could hinder progress and reduce the users' experience. Instead of heavy-handed regulation, they suggest encouraging self-regulation within the industry, fostering an environment where platforms voluntarily commit to ethical data use policies.
#
# Corporate Responsibility and Accountability
#
# Corporate responsibility is a significant facet of the discussion on regulation. Social media companies have wielded significant influence over societal norms and values, yet they often evade accountability for the negative effects of their platforms, such as cyberbullying, addiction, and the spread of misinformation. Regulation advocates argue that just like other influential industries, social media companies should be held accountable for their societal impacts.
#
# Mandatory regulations could impose standards for transparency and ethical conduct, requiring these entities to implement measures that prevent harm and misuse. For instance, platforms could be compelled to improve their algorithms to reduce the spread of false information or provide robust reporting systems for abuse.
#
# On the flip side, defenders of minimal regulation highlight the fast-paced nature of the digital world. They argue that government regulations often struggle to keep pace with technological advancements and that companies, being closer to the operational realities, are better positioned to implement effective solutions quickly. They also caution against stifling creativity and competitiveness in an industry that thrives on innovation.
#
# Public Safety and Regulation
#
# Public safety has become a central theme in the regulation debate, especially following incidents where social media has played a role in inciting violence or has been used as a platform for extremist ideologies. Advocates for regulation hold that government intervention is critical to prevent such abuses and ensure platforms do not become breeding grounds for harmful activities.
#
# Yet, critics warn that using safety as a premise for regulation could lead to excessive government control over online discourse. They propose alternative solutions such as enhancing collaboration between social media companies and non-governmental organizations to address these issues more effectively without infringing on individual liberties.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government is complex, with compelling arguments on both sides. On one hand, government regulation could provide necessary oversight, ensuring user safety and privacy while holding corporations accountable. On the other hand, it poses risks to free speech, innovation, and the free market. As technology continues to evolve, striking a balance between these competing interests remains paramount. Any regulatory framework should aim to protect individual rights and societal values, while fostering an environment where technological growth and innovation can flourish. Ultimately, the goal should be to create a digital space that is safe, inclusive, and conducive to constructive discourse.
#
# 🧠 Feedback:
#
# Here’s a professional critique of your essay on “Navigating the Digital Frontier: Should Social Media Platforms Be Regulated by the Government?” organized by structure, clarity, strength of argument, and writing style:
#
# 1. Structure
#   • Introduction
#     – Strengths: You open with context and immediately state the central question. Your roadmap (free speech, privacy, corporate responsibility, public safety) sets clear reader expectations.
#     – Suggestions: Condense slightly for a sharper thesis statement. For example, explicitly state your tentative stance (“This essay argues that…”) before diving into the themes.
#   • Body Sections
#     – Organization: Each theme gets its own paragraph or pair of paragraphs, which helps the reader follow your line of thought. Subheadings could further improve signposting.
#     – Transitions: At times the move from one theme to the next feels abrupt. Adding brief transition sentences (e.g. “Having examined free-speech implications, we now turn to privacy concerns…”) would smooth the flow.
#   • Conclusion
#     – Strengths: You successfully summarize both sides and call for a balanced approach.
#     – Suggestions: You might reinforce your own position a bit more strongly or suggest concrete next steps (e.g. a model regulatory body, phased implementation).
#
# 2. Clarity
#   • Voice and Tone: The prose is formal and accessible. Technical terms (GDPR, algorithms) are introduced with sufficient context.
#   • Precision: Occasionally statements veer toward the abstract (“digital ecosystem,” “societal values”) without concrete examples. Grounding claims with one or two brief case studies (e.g. Cambridge Analytica for privacy, Twitter’s handling of hate speech) would sharpen your points.
#   • Repetition: Some ideas—particularly “balance free speech with safety”—appear in multiple sections. You can consolidate to reduce redundancy.
#
# 3. Strength of Argument
#   • Balance: You do a good job of presenting both sides. This balanced approach lends credibility.
#   • Evidence: The essay is largely conceptual. Citing data (percentages of misinformation shared, legislative proposals under consideration) or referencing notable incidents adds weight to your claims.
#   • Depth:
#     – Free Speech/Censorship: You outline the classic free-speech versus censorship tension well. You could deepen it by discussing “safe harbors” (Section 230 in the U.S.), since that’s central to any regulation debate.
#     – Privacy: Mentioning GDPR is strong; you might contrast it with the U.S. regulatory landscape (e.g. CCPA in California) to highlight different approaches.
#     – Corporate Responsibility: Good call-outs on accountability. Perhaps suggest specific regulatory tools (mandatory reporting of algorithmic decision-making, independent audits).
#     – Public Safety: You note extremist misuse. Here you could reference collaboration frameworks (e.g. the Christchurch Call) to illustrate non-regulatory models in practice.
#
# 4. Writing Style
#   • Tone: Professional, objective, suitable for academic or policy audiences.
#   • Sentence Variety: Most sentences are moderate in length and structure. Introducing a few shorter, punchier sentences amid longer ones can enhance readability and emphasis.
#   • Jargon and Accessibility: You strike a good balance—specialized terms are explained and do not overwhelm the reader.
#   • Grammar and Syntax: No major errors. Watch out for passive constructions (“Platforms could be compelled…”) if you want a more active style (“Regulators should compel platforms…”).
#
# Overall, your essay is well organized and thoughtfully balanced. To elevate it further:
#   – Strengthen your thesis and conclusion with a clearer stance or call to action.
#   – Bolster arguments with specific examples, data, and references to current debates or legislation.
#   – Improve transitions and reduce repetition to keep the narrative tight.
#
# With these adjustments, your piece will be clearer, more persuasive, and more authoritative on this important public-policy question.
# ✍️ Revised:
#
# Title: Navigating the Digital Frontier: A Call for Government Regulation of Social Media Platforms
#
# Introduction
#
# In today's digital age, social media has become an integral part of our lives, significantly altering how we communicate, share information, and engage with the world. Platforms such as Facebook, Twitter, Instagram, and TikTok have not only redefined our social interactions but have also emerged as powerful tools for information dissemination, marketing, and political campaigning. However, the growing influence of these platforms raises an urgent question: should social media platforms be regulated by the government? This essay argues that government regulation is essential for addressing critical concerns such as free speech, privacy, corporate responsibility, and public safety, thereby ensuring a balanced digital ecosystem.
#
# Free Speech and Censorship
#
# A common argument against government regulation of social media is the potential threat to free speech. Social media platforms function as the modern public squares where diverse opinions are expressed and debated. Critics claim that government oversight might lead to increased censorship, suppressing minority or unpopular views and undermining democratic principles. However, while concerns about censorship are valid, it's essential to recognize that these platforms already regulate content through algorithms and moderation policies driven by corporate interests. Introducing government regulation could provide clearer guidelines and accountability, ensuring free speech is balanced with the protection of users from harmful content, misinformation, and hate speech. Understanding the nuances of "safe harbors," like Section 230 in the U.S., is vital for navigating these regulatory discussions.
#
# Privacy Concerns
#
# The issue of privacy is equally significant. Social media platforms collect substantial amounts of personal data, often used for targeted advertising and third-party sharing. Advocates of regulation argue that stringent laws are necessary to protect users' privacy rights and prevent data exploitation. The GDPR in the European Union exemplifies how government oversight can enforce transparency and data protection standards effectively. In contrast, opponents argue that harsh regulations might stifle innovation and growth in the tech industry. They propose self-regulation within the industry as a more flexible approach, promoting voluntary compliance with ethical data use policies. However, comparing GDPR with the U.S.'s CCPA reveals different regulatory landscapes, underscoring the need for a balanced regulatory framework.
#
# Corporate Responsibility and Accountability
#
# The role of corporate responsibility in the social media realm is pivotal. Platforms wield significant influence over societal norms and values but often evade accountability for negative impacts such as cyberbullying, addiction, and the spread of misinformation. Regulation proponents argue that social media companies, like other influential industries, should be held accountable. Mandatory regulations could enforce standards of transparency and ethical conduct, requiring platforms to implement measures against harm and misuse. For instance, platforms could be mandated to report algorithmic decision-making processes or undergo independent audits. Conversely, critics argue that the fast-paced nature of technology makes government regulations outdated by the time they are implemented. Maintaining minimal regulation, some assert, preserves creativity and competitiveness, essential to an industry driven by rapid innovation.
#
# Public Safety and Regulation
#
# Public safety has emerged as a central theme in the debate over regulation, particularly following incidents where social media has facilitated violence or extremist ideologies. Proponents argue for government intervention to prevent such abuses, maintaining that regulation is crucial to deter platforms from becoming hubs for harmful activities. However, critics caution against using safety as a pretext for excessive government control, potentially infringing on free speech. Exploring non-regulatory models, such as collaboration frameworks like the Christchurch Call, could offer alternative solutions that ensure public safety without compromising individual freedoms.
#
# Conclusion
#
# The debate on whether social media platforms should be regulated by the government is multifaceted, encompassing valid arguments both for and against oversight. Government regulation could provide necessary oversight to safeguard user safety and privacy, while ensuring corporate accountability. However, it also poses potential risks to free speech, innovation, and market dynamics. The challenge lies in crafting a regulatory framework that protects individual rights and societal values, fostering an environment conducive to technological growth and innovation. Ultimately, the goal should be to create a digital landscape that is safe, inclusive, and encourages constructive discourse. A balanced, phased approach to regulation, with clearly defined guidelines and collaborative models, could pave the way for a more secure and equitable digital future.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Digital Frontier: Should Social Media Platforms Be Regulated by the Government?
#
# Introduction
#
# In the digital age, social media has become an omnipresent force, shaping how we communicate, engage, and perceive the world. Platforms like Facebook, Twitter, Instagram, and TikTok have not only reshaped our social interactions but also positioned themselves as powerful tools for information dissemination, marketing, and political campaigning. However, their pervasive influence raises a critical question: should social media platforms be regulated by the government? This issue is complex and multi-faceted, touching on themes of free speech, censorship, privacy, corporate responsibility, and public safety. This essay will explore these angles to provide a nuanced perspective on whether government regulation is necessary or detrimental to the digital ecosystem.
#
# Free Speech and Censorship
#
# One of the primary arguments against government regulation of social media is the potential infringement on free speech. Social media platforms serve as modern-day public squares where individuals express opinions and engage in debates. Critics of regulation argue that government oversight could lead to censorship, stifling diverse voices and political dissent. They fear that allowing the government to dictate content standards could suppress unpopular or minority opinions, thereby weakening democratic principles.
#
# On the other hand, proponents of regulation contend that these platforms already exercise significant control over what is visible or hidden through their algorithms and moderation policies. They argue that without oversight, social media giants can continue to act as gatekeepers of information, often driven by corporate interests rather than the public good. Regulating these platforms could establish clear guidelines and accountability, ensuring that free speech is balanced with the need to protect users from harmful content, misinformation, and hate speech.
#
# Privacy Concerns
#
# Another compelling angle involves privacy concerns. Social media platforms collect vast amounts of personal data from their users, which is often used for targeted advertising and third-party sharing. Advocates for regulation argue that stringent laws are necessary to protect users' privacy rights and prevent data exploitation. The General Data Protection Regulation (GDPR) in the European Union serves as an example of how government regulation can enforce transparency and data protection standards.
#
# Conversely, opponents argue that overly strict regulations could stifle innovation and growth within the tech industry. They believe that companies should have the freedom to develop technologies that maximize user engagement and business success, maintaining that any restrictions could hinder progress and reduce the users' experience. Instead of heavy-handed regulation, they suggest encouraging self-regulation within the industry, fostering an environment where platforms voluntarily commit to ethical data use policies.
#
# Corporate Responsibility and Accountability
#
# Corporate responsibility is a significant facet of the discussion on regulation. Social media companies have wielded significant influence over societal norms and values, yet they often evade accountability for the negative effects of their platforms, such as cyberbullying, addiction, and the spread of misinformation. Regulation advocates argue that just like other influential industries, social media companies should be held accountable for their societal impacts.
#
# Mandatory regulations could impose standards for transparency and ethical conduct, requiring these entities to implement measures that prevent harm and misuse. For instance, platforms could be compelled to improve their algorithms to reduce the spread of false information or provide robust reporting systems for abuse.
#
# On the flip side, defenders of minimal regulation highlight the fast-paced nature of the digital world. They argue that government regulations often struggle to keep pace with technological advancements and that companies, being closer to the operational realities, are better positioned to implement effective solutions quickly. They also caution against stifling creativity and competitiveness in an industry that thrives on innovation.
#
# Public Safety and Regulation
#
# Public safety has become a central theme in the regulation debate, especially following incidents where social media has played a role in inciting violence or has been used as a platform for extremist ideologies. Advocates for regulation hold that government intervention is critical to prevent such abuses and ensure platforms do not become breeding grounds for harmful activities.
#
# Yet, critics warn that using safety as a premise for regulation could lead to excessive government control over online discourse. They propose alternative solutions such as enhancing collaboration between social media companies and non-governmental organizations to address these issues more effectively without infringing on individual liberties.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government is complex, with compelling arguments on both sides. On one hand, government regulation could provide necessary oversight, ensuring user safety and privacy while holding corporations accountable. On the other hand, it poses risks to free speech, innovation, and the free market. As technology continues to evolve, striking a balance between these competing interests remains paramount. Any regulatory framework should aim to protect individual rights and societal values, while fostering an environment where technological growth and innovation can flourish. Ultimately, the goal should be to create a digital space that is safe, inclusive, and conducive to constructive discourse.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here’s a professional critique of your essay on “Navigating the Digital Frontier: Should Social Media Platforms Be Regulated by the Government?” organized by structure, clarity, strength of argument, and writing style:
#
# 1. Structure
#   • Introduction
#     – Strengths: You open with context and immediately state the central question. Your roadmap (free speech, privacy, corporate responsibility, public safety) sets clear reader expectations.
#     – Suggestions: Condense slightly for a sharper thesis statement. For example, explicitly state your tentative stance (“This essay argues that…”) before diving into the themes.
#   • Body Sections
#     – Organization: Each theme gets its own paragraph or pair of paragraphs, which helps the reader follow your line of thought. Subheadings could further improve signposting.
#     – Transitions: At times the move from one theme to the next feels abrupt. Adding brief transition sentences (e.g. “Having examined free-speech implications, we now turn to privacy concerns…”) would smooth the flow.
#   • Conclusion
#     – Strengths: You successfully summarize both sides and call for a balanced approach.
#     – Suggestions: You might reinforce your own position a bit more strongly or suggest concrete next steps (e.g. a model regulatory body, phased implementation).
#
# 2. Clarity
#   • Voice and Tone: The prose is formal and accessible. Technical terms (GDPR, algorithms) are introduced with sufficient context.
#   • Precision: Occasionally statements veer toward the abstract (“digital ecosystem,” “societal values”) without concrete examples. Grounding claims with one or two brief case studies (e.g. Cambridge Analytica for privacy, Twitter’s handling of hate speech) would sharpen your points.
#   • Repetition: Some ideas—particularly “balance free speech with safety”—appear in multiple sections. You can consolidate to reduce redundancy.
#
# 3. Strength of Argument
#   • Balance: You do a good job of presenting both sides. This balanced approach lends credibility.
#   • Evidence: The essay is largely conceptual. Citing data (percentages of misinformation shared, legislative proposals under consideration) or referencing notable incidents adds weight to your claims.
#   • Depth:
#     – Free Speech/Censorship: You outline the classic free-speech versus censorship tension well. You could deepen it by discussing “safe harbors” (Section 230 in the U.S.), since that’s central to any regulation debate.
#     – Privacy: Mentioning GDPR is strong; you might contrast it with the U.S. regulatory landscape (e.g. CCPA in California) to highlight different approaches.
#     – Corporate Responsibility: Good call-outs on accountability. Perhaps suggest specific regulatory tools (mandatory reporting of algorithmic decision-making, independent audits).
#     – Public Safety: You note extremist misuse. Here you could reference collaboration frameworks (e.g. the Christchurch Call) to illustrate non-regulatory models in practice.
#
# 4. Writing Style
#   • Tone: Professional, objective, suitable for academic or policy audiences.
#   • Sentence Variety: Most sentences are moderate in length and structure. Introducing a few shorter, punchier sentences amid longer ones can enhance readability and emphasis.
#   • Jargon and Accessibility: You strike a good balance—specialized terms are explained and do not overwhelm the reader.
#   • Grammar and Syntax: No major errors. Watch out for passive constructions (“Platforms could be compelled…”) if you want a more active style (“Regulators should compel platforms…”).
#
# Overall, your essay is well organized and thoughtfully balanced. To elevate it further:
#   – Strengthen your thesis and conclusion with a clearer stance or call to action.
#   – Bolster arguments with specific examples, data, and references to current debates or legislation.
#   – Improve transitions and reduce repetition to keep the narrative tight.
#
# With these adjustments, your piece will be clearer, more persuasive, and more authoritative on this important public-policy question.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Digital Frontier: A Call for Government Regulation of Social Media Platforms
#
# Introduction
#
# In today's digital age, social media has become an integral part of our lives, significantly altering how we communicate, share information, and engage with the world. Platforms such as Facebook, Twitter, Instagram, and TikTok have not only redefined our social interactions but have also emerged as powerful tools for information dissemination, marketing, and political campaigning. However, the growing influence of these platforms raises an urgent question: should social media platforms be regulated by the government? This essay argues that government regulation is essential for addressing critical concerns such as free speech, privacy, corporate responsibility, and public safety, thereby ensuring a balanced digital ecosystem.
#
# Free Speech and Censorship
#
# A common argument against government regulation of social media is the potential threat to free speech. Social media platforms function as the modern public squares where diverse opinions are expressed and debated. Critics claim that government oversight might lead to increased censorship, suppressing minority or unpopular views and undermining democratic principles. However, while concerns about censorship are valid, it's essential to recognize that these platforms already regulate content through algorithms and moderation policies driven by corporate interests. Introducing government regulation could provide clearer guidelines and accountability, ensuring free speech is balanced with the protection of users from harmful content, misinformation, and hate speech. Understanding the nuances of "safe harbors," like Section 230 in the U.S., is vital for navigating these regulatory discussions.
#
# Privacy Concerns
#
# The issue of privacy is equally significant. Social media platforms collect substantial amounts of personal data, often used for targeted advertising and third-party sharing. Advocates of regulation argue that stringent laws are necessary to protect users' privacy rights and prevent data exploitation. The GDPR in the European Union exemplifies how government oversight can enforce transparency and data protection standards effectively. In contrast, opponents argue that harsh regulations might stifle innovation and growth in the tech industry. They propose self-regulation within the industry as a more flexible approach, promoting voluntary compliance with ethical data use policies. However, comparing GDPR with the U.S.'s CCPA reveals different regulatory landscapes, underscoring the need for a balanced regulatory framework.
#
# Corporate Responsibility and Accountability
#
# The role of corporate responsibility in the social media realm is pivotal. Platforms wield significant influence over societal norms and values but often evade accountability for negative impacts such as cyberbullying, addiction, and the spread of misinformation. Regulation proponents argue that social media companies, like other influential industries, should be held accountable. Mandatory regulations could enforce standards of transparency and ethical conduct, requiring platforms to implement measures against harm and misuse. For instance, platforms could be mandated to report algorithmic decision-making processes or undergo independent audits. Conversely, critics argue that the fast-paced nature of technology makes government regulations outdated by the time they are implemented. Maintaining minimal regulation, some assert, preserves creativity and competitiveness, essential to an industry driven by rapid innovation.
#
# Public Safety and Regulation
#
# Public safety has emerged as a central theme in the debate over regulation, particularly following incidents where social media has facilitated violence or extremist ideologies. Proponents argue for government intervention to prevent such abuses, maintaining that regulation is crucial to deter platforms from becoming hubs for harmful activities. However, critics caution against using safety as a pretext for excessive government control, potentially infringing on free speech. Exploring non-regulatory models, such as collaboration frameworks like the Christchurch Call, could offer alternative solutions that ensure public safety without compromising individual freedoms.
#
# Conclusion
#
# The debate on whether social media platforms should be regulated by the government is multifaceted, encompassing valid arguments both for and against oversight. Government regulation could provide necessary oversight to safeguard user safety and privacy, while ensuring corporate accountability. However, it also poses potential risks to free speech, innovation, and market dynamics. The challenge lies in crafting a regulatory framework that protects individual rights and societal values, fostering an environment conducive to technological growth and innovation. Ultimately, the goal should be to create a digital landscape that is safe, inclusive, and encourages constructive discourse. A balanced, phased approach to regulation, with clearly defined guidelines and collaborative models, could pave the way for a more secure and equitable digital future.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
